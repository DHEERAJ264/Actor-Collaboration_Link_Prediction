# %%
import networkx as nx
import matplotlib.pyplot as plt
import time
d = nx.read_edgelist(r'C:/Users/student/Documents/Network Science_Dheeraj/Final Project/out.actor-collaboration', create_using= nx.Graph())

# %%
d.degree
# Out:
# DegreeView({'1': 18, '2': 1, '3': 15, '4': 14, '5': 5, '6': 48, '7': 10, '8': 3, '9': 3, '10': 3, '11': 171, '12': 36, '13': 94, '14': 18, '15': 42, '16': 30, '17': 9, '18': 31, '19': 24, '20': 1, '21': 13, '22': 1, '23': 16, '24': 5, '25': 4, '26': 4, '27': 35, '28': 4, '29': 1, '30': 1, '31': 1, '32': 1, '33': 5, '34': 5, '35': 1, '36': 1, '37': 4, '38': 4, '39': 4, '40': 4, '41': 4, '42': 47, '43': 23, '44': 240, '45': 134, '46': 130, '47': 98, '48': 64, '49': 23, '50': 23, '51': 50, '52': 37, '53': 63, '54': 54, '55': 23, '56': 37, '57': 23, '58': 70, '59': 34, '60': 23, '61': 57, '62': 23, '63': 23, '64': 61, '65': 102, '66': 17, '67': 17, '68': 17, '69': 26, '70': 17, '71': 17, '72': 17, '73': 17, '74': 17, '75': 17, '76': 29, '77': 17, '78': 17, '79': 17, '80': 17, '81': 17, '82': 17, '83': 140, '84': 20, '85': 95, '86': 17, '87': 95, '88': 121, '89': 79, '90': 64, '91': 14, '92': 2, '93': 47, '94': 28, '95': 22, '96': 206, '97': 11, '98': 52, '99': 64, '100': 11, '101': 51, '
# ...

# %%
remove = [node for node,degree in d.degree() if degree < 2]

# %%
remove
# Out:
# ['2',
#  '20',
#  '22',
#  '29',
#  '30',
#  '31',
#  '32',
#  '35',
#  '36',
#  '160',
#  '161',
#  '218',
#  '298',
#  '306',
#  '307',
#  '338',
#  '339',
#  '340',
#  '341',
#  '353',
#  '354',
#  '367',
#  '371',
#  '377',
#  '386',
#  '387',
#  '388',
#  '389',
#  '623',
#  '672',
#  '688',
#  '708',
#  '758',
#  '1392',
#  '1399',
#  '1430',
#  '1459',
#  '1657',
#  '1777',
#  '1789',
#  '2011',
#  '2020',
#  '2941',
#  '3070',
#  '3082',
#  '3780',
#  '4055',
#  '4197',
#  '4253',
#  '4258',
#  '4286',
#  '4293',
#  '4608',
#  '5062',
#  '5071',
#  '5079',
#  '5180',
#  '5290',
#  '5328',
#  '5329',
#  '5336',
#  '5400',
#  '5415',
#  '5428',
#  '5451',
#  '5730',
#  '5731',
#  '5802',
#  '5838',
#  '5898',
#  '5899',
#  '5900',
#  '5905',
#  '5916',
#  '5925',
#  '5979',
#  '6183',
#  '6188',
#  '6189',
#  '6270',
#  '6271',
#  '6272']

# %%
d.remove_nodes_from(remove)

# %%
new = d.nodes

# %%
 new_data1 = d.edges

# %%
import csv
csvfile = "C:/Users/student/Documents/Network Science_Dheeraj/Final Project/new_data1.csv"

#Assuming res is a flat list
with open(csvfile, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in new_data1:
        writer.writerow([val])    

#Assuming res is a list of lists
with open(csvfile, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    writer.writerows(new_data1)
